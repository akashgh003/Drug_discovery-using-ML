# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('bioactivity_butyrylcholinesterase_preprocessed_data.csv')
df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 3767      CHEMBL5220093  COc1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(O)CCN(C(C)=O)[...
# 3768      CHEMBL5218447  CN(CCCOc1ccc2ccc(=O)oc2c1)Cc1cccc(OC(=O)NC2CCC...
# 3769      CHEMBL5220375  CN(CCCOc1ccc2ccc(=O)oc2c1)Cc1cccc(OC(=O)NC2CCC...
# 3770      CHEMBL5218952             C#CCN1CCC(CCc2cccc(OC(=O)N(C)CC)c2)CC1
# 3771      CHEMBL5220219          C#CCN1CCC(CCc2cccc(OC(=O)Nc3ccccc3)c2)CC1
#
#       standard_value
# 0             920.00
# 1             900.00
# ...

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------------

# %%
df["standard_value"].describe()
# Out:
# count    3.771000e+03
# mean     5.419521e+12
# std      3.038358e+14
# min      1.000000e-05
# 25%      2.012500e+02
# 50%      3.500000e+03
# 75%      2.210500e+04
# max      1.862087e+16
# Name: standard_value, dtype: float64

# %%
stdDf = df["standard_value"]
stdDf = stdDf / 1000
stdDf.describe()
# Out:
# count    6.156000e+03
# mean     1.064838e+02
# std      9.218820e+02
# min      5.000000e-09
# 25%      1.480000e-01
# 50%      2.300000e+00
# 75%      1.700000e+01
# max      4.960000e+04
# Name: standard_value, dtype: float64

# %%
zero_standard_value_rows = df[df['standard_value'] == 0]
zero_standard_value_rows
# Out:
# Empty DataFrame
# Columns: [molecule_chembl_id, canonical_smiles, standard_value]
# Index: []

# %%
df = df.drop(df[df['standard_value'] == 0].index)

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------------

# %%
df['pIC50'] = np.log10(df['standard_value'] * 1e-9) * (-1)

# %%
df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 6151      CHEMBL5219841         COc1cccc2c1CCCC2NS(=O)(=O)NC(=O)OCc1ccccc1
# 6152      CHEMBL5219046      CC[C@@]1(c2cccc(OC(=O)Nc3ccccc3)c2)CCCCN(C)C1
# 6153      CHEMBL5219594             O=c1[nH]c2ccc(OCc3ccc(F)cc3)cc2c(=O)o1
# 6154      CHEMBL5219958         CC(C)c1ccc(COc2ccc3[nH]c(=O)oc(=O)c3c2)cc1
# 6155      CHEMBL5220884  Cn1ccc2cc(-c3cnc4ccc(C(=O)N5CCCCC5)cc4n3)ccc2c1=O
#
#       standard_value     pIC50
# 0            750.000  6.124939
# ...

# %%
df['pIC50'].describe()
# Out:
# count    3771.000000
# mean        5.739980
# std         1.593896
# min        -7.270000
# 25%         4.655510
# 50%         5.455932
# 75%         6.696264
# max        14.000000
# Name: pIC50, dtype: float64

# %%
df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 3767      CHEMBL5220093  COc1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(O)CCN(C(C)=O)[...
# 3768      CHEMBL5218447  CN(CCCOc1ccc2ccc(=O)oc2c1)Cc1cccc(OC(=O)NC2CCC...
# 3769      CHEMBL5220375  CN(CCCOc1ccc2ccc(=O)oc2c1)Cc1cccc(OC(=O)NC2CCC...
# 3770      CHEMBL5218952             C#CCN1CCC(CCc2cccc(OC(=O)N(C)CC)c2)CC1
# 3771      CHEMBL5220219          C#CCN1CCC(CCc2cccc(OC(=O)Nc3ccccc3)c2)CC1
#
#       standard_value     pIC50
# 0             920.00  6.036212
# ...

# %%
df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 3767      CHEMBL5220093  COc1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(O)CCN(C(C)=O)[...
# 3768      CHEMBL5218447  CN(CCCOc1ccc2ccc(=O)oc2c1)Cc1cccc(OC(=O)NC2CCC...
# 3769      CHEMBL5220375  CN(CCCOc1ccc2ccc(=O)oc2c1)Cc1cccc(OC(=O)NC2CCC...
# 3770      CHEMBL5218952             C#CCN1CCC(CCc2cccc(OC(=O)N(C)CC)c2)CC1
# 3771      CHEMBL5220219          C#CCN1CCC(CCc2cccc(OC(=O)Nc3ccccc3)c2)CC1
#
#       standard_value     pIC50
# 0             920.00  6.036212
# ...

# %%
df = df.drop('standard_value', axis=1)

# %%
df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 3767      CHEMBL5220093  COc1ccc(NC(=O)Oc2ccc3c(c2)[C@]2(O)CCN(C(C)=O)[...
# 3768      CHEMBL5218447  CN(CCCOc1ccc2ccc(=O)oc2c1)Cc1cccc(OC(=O)NC2CCC...
# 3769      CHEMBL5220375  CN(CCCOc1ccc2ccc(=O)oc2c1)Cc1cccc(OC(=O)NC2CCC...
# 3770      CHEMBL5218952             C#CCN1CCC(CCc2cccc(OC(=O)N(C)CC)c2)CC1
# 3771      CHEMBL5220219          C#CCN1CCC(CCc2cccc(OC(=O)Nc3ccccc3)c2)CC1
#
#          pIC50
# 0     6.036212
# 1     6.045757
# 2     4.301030
# ...

# %%
df.to_csv('pIC50_dataset_butyrylcholinesterase.csv', index=False)
